# %% [markdown]
# # Regularizations Techniques
#
# In this task, you are going to experiment with two popular regularization methods.
#
# ** Dropout:** In the last assignment, you have trained a shallow network and everything looked fine. However, when the network becomes larger and deeper, it will also become harder to train. The first potential problem is over-fitting, that is, the network overreacts to noise or random errors of the training data, while it fails to detect the underlying distribution pattern. It is more likely to occur when the model becomes complex and contains more trainable parameters. Dropout is a well-known method that can eliminate such effects. The core idea behind it is quite simple, ie., rather than updating all trainable parameters each time, it randomly selects a subset of parameters to update and keeps other parameters unaltered.
#
#
#
# ** Batch normalization:** Batch normalization makes it possible to train a deep network. When a network becomes deeper, the distribution of hidden neurons' values will also shift greatly, and that is one reason that makes it hard to train a deep neural network. Machine learning teaches that normalization is a good preprocessing method to deal with such a problem. So  batch normalization deploys a similar idea in the neural network. It re-normalizes the hidden values of each layer before transfering values to the next layer.
#
#
# * References
#     * https://www.cs.toronto.edu/~hinton/absps/JMLRdropout.pdf
#     * https://arxiv.org/pdf/1502.03167.pdf
#     * https://www.tensorflow.org/api_docs/python/tf/contrib/layers/batch_norm
#     * https://github.com/tensorflow/tensorflow/blob/r1.3/tensorflow/contrib/layers/python/layers/layers.py
#     * https://www.tensorflow.org/api_docs/python/tf/nn/batch_normalization

# %%
% matplotlib inline
% load_ext autoreload
% autoreload 2

# Import modules
from __future__ import print_function
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from ecbm4040.cifar_utils import load_data

# %% [markdown]
# ## Load Data

# %%
# Load the raw CIFAR-10 data.
X_train, y_train, X_test, y_test = load_data()
X_val = X_train[:500,:]
y_val = y_train[:500]
X_train = X_train[500:2500,:]
y_train = y_train[500:2500]

mean_image = np.mean(X_train, axis=0).astype(np.float32)
X_train = X_train.astype(np.float32) - mean_image
X_val = X_val.astype(np.float32) - mean_image

# We've vectorized the data for you. That is, we flatten the 32×32×3 images into 1×3072 Numpy arrays.
print('Training data shape: ', X_train.shape)
print('Training labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
# Out:
# ./data/cifar-10-python.tar.gz already exists. Begin extracting...
# Training data shape:  (2000, 3072)
# Training labels shape:  (2000,)
# Validation data shape:  (500, 3072)
# Validation labels shape:  (500,)

# %% [markdown]
# ## Part 1: Dropout

# %% [markdown]
# ### Implement dropout foward function

# %%
x_in = np.random.randn(500, 500) + 10

# %%
from ecbm4040.reg_funcs import dropout_forward
from ecbm4040.reg_funcs import dropout_backward

p = 0.5
dropout_config = {"enabled": True, "keep_prob": p}
# feedforward
out, cache = dropout_forward(x=x_in, dropout_config=dropout_config, mode="train")
out_test, _ = dropout_forward(x=x_in, dropout_config=dropout_config, mode="test") 
# backward
dout = np.ones_like(x_in)
dx = dropout_backward(dout, cache)
#######################################
# Checking code. Don't change it.     #
#######################################
# Check forward correctness
print("mean_of_input = {}".format(p*np.mean(x_in)))
print("mean_of_out = {}".format(np.mean(out)))
print("mean_of_out_test = {}".format(np.mean(out_test)))
# Out:
# mean_of_input = 4.999509837112702
# mean_of_out = 10.00882696988847
# mean_of_out_test = 9.999019674225403

# %% [markdown]
# ### Experiments with MLP
#
# 1. Add dropout into MLP. Please review **loss**, **predict** function of class **MLP** in **./ecbm4040/neuralnets/mlp.py**, and understand how **dropout** is added into MLP.
#
# 2. Customize your own MLP network.Then, train networks with different **keep_prob**, like 0.1, 0.5, 0.7, 0.9, 1. If **keep_prob**==1, then the network become the normal MLP without dropout.
#
# 3. Plot the loss, train accuracy and valid accuracy curve.

# %%
from ecbm4040.neuralnets.mlp import MLP 
from ecbm4040.optimizers import AdamOptim

# %%
# Here is an example on how to collect loss and accuracy info
dropout_config = {"enabled":True, "keep_prob": 1}
model = MLP(input_dim=3072, hidden_dims=[200], num_classes=10, 
            weight_scale=1e-3, l2_reg=0.0, dropout_config=dropout_config)
optimizer = AdamOptim(model)
# hist_no_dropout contains loss, train acc and valid acc history.
hist_no_dropout = optimizer.train(model, X_train, y_train, X_val, y_val, 
                           num_epoch=20, batch_size=100, learning_rate=1e-3, learning_decay=0.95, 
                           verbose=False, record_interval = 4)
print(hist_no_dropout[0])
print(hist_no_dropout[1])
print(hist_no_dropout[2])
# Out:
# number of batches for training: 20
# epoch 1: valid acc = 0.202, new learning rate = 0.00095
# epoch 2: valid acc = 0.278, new learning rate = 0.0009025
# epoch 3: valid acc = 0.336, new learning rate = 0.000857375
# epoch 4: valid acc = 0.346, new learning rate = 0.0008145062499999999
# epoch 5: valid acc = 0.358, new learning rate = 0.0007737809374999998
# epoch 6: valid acc = 0.326, new learning rate = 0.0007350918906249997
# epoch 7: valid acc = 0.336, new learning rate = 0.0006983372960937497
# epoch 8: valid acc = 0.358, new learning rate = 0.0006634204312890621
# epoch 9: valid acc = 0.368, new learning rate = 0.000630249409724609
# epoch 10: valid acc = 0.35, new learning rate = 0.0005987369392383785
# epoch 11: valid acc = 0.354, new learning rate = 0.0005688000922764595
# epoch 12: valid acc = 0.354, new learning rate = 0.0005403600876626365
# epoch 13: valid acc = 0.338, new learning rate = 0.0005133420832795047
# epoch 14: valid acc = 0.336, new learning rate = 0.00048767497911552944
# epoch 15: valid acc = 0.37, new learning rate = 0.00046329123015975297
# epoch 16: valid acc = 0.368, new learning rate = 0.0004401266686517653
# epoch 17: valid acc = 0.366, new learning rate = 0.00041812033521917703
# epoch 18: valid acc = 0.368, new learning rate = 0.00039721431845821814
# epoch 19: valid acc = 0.362, new learning rate = 0.0003773536025353072
# epoch 20: valid acc = 0.364, new learning rate = 0.0003584859224085418
# [3.211903152132797, 3.8784792891218807, 3.9185321758989988, 3.2562843950840632, 3.4662746183748911, 3.3890835640514365, 2.6617899593299894, 2.5591931146108804, 2.4912416047742747, 2.0246311329099811, 2.2072254035514547, 2.0042098304525924, 1.8999996313301815, 1.9764078182293803, 1.8247770642575598, 1.8830275242778947, 1.745105427632514, 1.6998219598278226, 1.795224413476509, 1.6541799401546737, 1.7403415689753419, 1.6071801324626798, 1.5902769257395977, 1.7020323415554077, 1.5839835821477879, 1.6457544825824288, 1.5049757952230338, 1.5037835569202858, 1.5856475080872936, 1.5199125572405245, 1.5842661939692193, 1.4148423930240073, 1.3915952801900062, 1.48924348902318, 1.4266495457150163, 1.4679259983605264, 1.3759059221626839, 1.3253020090190086, 1.4544017861523211, 1.3587216952897616, 1.3855161601274462, 1.3049780041430388, 1.2534050194731057, 1.3573249107494803, 1.3009084633515089, 1.3099233572565134, 1.2283103860284519, 1.2030965883308993, 1.3051505283054747, 1.2417621019157625, 1.2438906876821618, 1.2063782773630731, 1.1494674334041601, 1.2586071206910125, 1.1963024900034585, 1.1825334391326783, 1.2011340180594365, 1.0994345821234759, 1.2231360190608236, 1.1440364450901082, 1.1447484707758036, 1.1719240569211062, 1.0750830782845273, 1.1762334521071192, 1.136332453676675, 1.1124540939449086, 1.128911965080192, 1.0333886763401994, 1.1036860606100103, 1.070167068295578, 1.0757897508936816, 1.0551789834692797, 0.98750563549825099, 1.056222929995865, 1.0397797076427731, 1.023810453410323, 1.0173177522239585, 0.93756487799022104, 1.0302551837174367, 1.0065011408732267, 0.98429255018298356, 0.993943732774204, 0.89206809792828357, 0.99156106880478112, 0.96406556864550497, 0.93302744207677213, 0.92863321356557449, 0.88113269391519322, 0.95577422797454914, 0.9217336333048689, 0.90090130054012951, 0.89318700595473099, 0.82738472357032244, 0.92697565064695198, 0.89010747366272802, 0.86312234856916636, 0.87909147475784788, 0.7878637043895258, 0.89257157879194948, 0.87047724397496629]
# [0.23050000000000001, 0.35099999999999998, 0.4385, 0.47949999999999998, 0.51600000000000001, 0.52249999999999996, 0.56399999999999995, 0.59899999999999998, 0.63149999999999995, 0.64900000000000002, 0.65649999999999997, 0.6825, 0.67300000000000004, 0.67749999999999999, 0.69750000000000001, 0.73750000000000004, 0.74099999999999999, 0.74299999999999999, 0.75849999999999995, 0.79500000000000004]
# [0.20200000000000001, 0.27800000000000002, 0.33600000000000002, 0.34599999999999997, 0.35799999999999998, 0.32600000000000001, 0.33600000000000002, 0.35799999999999998, 0.36799999999999999, 0.34999999999999998, 0.35399999999999998, 0.35399999999999998, 0.33800000000000002, 0.33600000000000002, 0.37, 0.36799999999999999, 0.36599999999999999, 0.36799999999999999, 0.36199999999999999, 0.36399999999999999]

# %%
# small retention rate
dropout_config = {"enabled":True, "keep_prob": 0.1}
model = MLP(input_dim=3072, hidden_dims=[200], num_classes=10, 
            weight_scale=1e-3, l2_reg=0.0, dropout_config=dropout_config)
optimizer = AdamOptim(model)
# hist_no_dropout contains loss, train acc and valid acc history.
hist_dropout_01 = optimizer.train(model, X_train, y_train, X_val, y_val, 
                           num_epoch=20, batch_size=100, learning_rate=1e-3, learning_decay=0.95, 
                           verbose=False, record_interval = 4)
# Out:
# number of batches for training: 20
# epoch 1: valid acc = 0.182, new learning rate = 0.00095
# epoch 2: valid acc = 0.248, new learning rate = 0.0009025
# epoch 3: valid acc = 0.3, new learning rate = 0.000857375
# epoch 4: valid acc = 0.286, new learning rate = 0.0008145062499999999
# epoch 5: valid acc = 0.286, new learning rate = 0.0007737809374999998
# epoch 6: valid acc = 0.358, new learning rate = 0.0007350918906249997
# epoch 7: valid acc = 0.336, new learning rate = 0.0006983372960937497
# epoch 8: valid acc = 0.34, new learning rate = 0.0006634204312890621
# epoch 9: valid acc = 0.334, new learning rate = 0.000630249409724609
# epoch 10: valid acc = 0.346, new learning rate = 0.0005987369392383785
# epoch 11: valid acc = 0.368, new learning rate = 0.0005688000922764595
# epoch 12: valid acc = 0.354, new learning rate = 0.0005403600876626365
# epoch 13: valid acc = 0.35, new learning rate = 0.0005133420832795047
# epoch 14: valid acc = 0.336, new learning rate = 0.00048767497911552944
# epoch 15: valid acc = 0.362, new learning rate = 0.00046329123015975297
# epoch 16: valid acc = 0.366, new learning rate = 0.0004401266686517653
# epoch 17: valid acc = 0.346, new learning rate = 0.00041812033521917703
# epoch 18: valid acc = 0.372, new learning rate = 0.00039721431845821814
# epoch 19: valid acc = 0.36, new learning rate = 0.0003773536025353072
# epoch 20: valid acc = 0.35, new learning rate = 0.0003584859224085418

# %%
# keep prob 0.5
dropout_config = {"enabled":True, "keep_prob": 0.5}
model = MLP(input_dim=3072, hidden_dims=[200], num_classes=10, 
            weight_scale=1e-3, l2_reg=0.0, dropout_config=dropout_config)
optimizer = AdamOptim(model)
# hist_no_dropout contains loss, train acc and valid acc history.
hist_dropout_05 = optimizer.train(model, X_train, y_train, X_val, y_val, 
                           num_epoch=20, batch_size=100, learning_rate=1e-3, learning_decay=0.95, 
                           verbose=False, record_interval = 4)
# Out:
# number of batches for training: 20
# epoch 1: valid acc = 0.276, new learning rate = 0.00095
# epoch 2: valid acc = 0.276, new learning rate = 0.0009025
# epoch 3: valid acc = 0.282, new learning rate = 0.000857375
# epoch 4: valid acc = 0.308, new learning rate = 0.0008145062499999999
# epoch 5: valid acc = 0.352, new learning rate = 0.0007737809374999998
# epoch 6: valid acc = 0.32, new learning rate = 0.0007350918906249997
# epoch 7: valid acc = 0.368, new learning rate = 0.0006983372960937497
# epoch 8: valid acc = 0.34, new learning rate = 0.0006634204312890621
# epoch 9: valid acc = 0.374, new learning rate = 0.000630249409724609
# epoch 10: valid acc = 0.354, new learning rate = 0.0005987369392383785
# epoch 11: valid acc = 0.37, new learning rate = 0.0005688000922764595
# epoch 12: valid acc = 0.384, new learning rate = 0.0005403600876626365
# epoch 13: valid acc = 0.356, new learning rate = 0.0005133420832795047
# epoch 14: valid acc = 0.368, new learning rate = 0.00048767497911552944
# epoch 15: valid acc = 0.39, new learning rate = 0.00046329123015975297
# epoch 16: valid acc = 0.362, new learning rate = 0.0004401266686517653
# epoch 17: valid acc = 0.384, new learning rate = 0.00041812033521917703
# epoch 18: valid acc = 0.37, new learning rate = 0.00039721431845821814
# epoch 19: valid acc = 0.396, new learning rate = 0.0003773536025353072
# epoch 20: valid acc = 0.384, new learning rate = 0.0003584859224085418

# %%
# keep prob 0.7
dropout_config = {"enabled":True, "keep_prob": 0.7}
model = MLP(input_dim=3072, hidden_dims=[200], num_classes=10, 
            weight_scale=1e-3, l2_reg=0.0, dropout_config=dropout_config)
optimizer = AdamOptim(model)
# hist_no_dropout contains loss, train acc and valid acc history.
hist_dropout_07 = optimizer.train(model, X_train, y_train, X_val, y_val, 
                           num_epoch=20, batch_size=100, learning_rate=1e-3, learning_decay=0.95, 
                           verbose=False, record_interval = 4)
# Out:
# number of batches for training: 20
# epoch 1: valid acc = 0.254, new learning rate = 0.00095
# epoch 2: valid acc = 0.238, new learning rate = 0.0009025
# epoch 3: valid acc = 0.296, new learning rate = 0.000857375
# epoch 4: valid acc = 0.328, new learning rate = 0.0008145062499999999
# epoch 5: valid acc = 0.342, new learning rate = 0.0007737809374999998
# epoch 6: valid acc = 0.334, new learning rate = 0.0007350918906249997
# epoch 7: valid acc = 0.336, new learning rate = 0.0006983372960937497
# epoch 8: valid acc = 0.362, new learning rate = 0.0006634204312890621
# epoch 9: valid acc = 0.38, new learning rate = 0.000630249409724609
# epoch 10: valid acc = 0.356, new learning rate = 0.0005987369392383785
# epoch 11: valid acc = 0.366, new learning rate = 0.0005688000922764595
# epoch 12: valid acc = 0.376, new learning rate = 0.0005403600876626365
# epoch 13: valid acc = 0.346, new learning rate = 0.0005133420832795047
# epoch 14: valid acc = 0.366, new learning rate = 0.00048767497911552944
# epoch 15: valid acc = 0.38, new learning rate = 0.00046329123015975297
# epoch 16: valid acc = 0.372, new learning rate = 0.0004401266686517653
# epoch 17: valid acc = 0.374, new learning rate = 0.00041812033521917703
# epoch 18: valid acc = 0.378, new learning rate = 0.00039721431845821814
# epoch 19: valid acc = 0.366, new learning rate = 0.0003773536025353072
# epoch 20: valid acc = 0.364, new learning rate = 0.0003584859224085418

# %%
# keep prob 0.9
dropout_config = {"enabled":True, "keep_prob": 0.9}
model = MLP(input_dim=3072, hidden_dims=[200], num_classes=10, 
            weight_scale=1e-3, l2_reg=0.0, dropout_config=dropout_config)
optimizer = AdamOptim(model)
# hist_no_dropout contains loss, train acc and valid acc history.
hist_dropout_09 = optimizer.train(model, X_train, y_train, X_val, y_val, 
                           num_epoch=20, batch_size=100, learning_rate=1e-3, learning_decay=0.95, 
                           verbose=False, record_interval = 4)
# Out:
# number of batches for training: 20
# epoch 1: valid acc = 0.216, new learning rate = 0.00095
# epoch 2: valid acc = 0.29, new learning rate = 0.0009025
# epoch 3: valid acc = 0.294, new learning rate = 0.000857375
# epoch 4: valid acc = 0.312, new learning rate = 0.0008145062499999999
# epoch 5: valid acc = 0.328, new learning rate = 0.0007737809374999998
# epoch 6: valid acc = 0.348, new learning rate = 0.0007350918906249997
# epoch 7: valid acc = 0.324, new learning rate = 0.0006983372960937497
# epoch 8: valid acc = 0.342, new learning rate = 0.0006634204312890621
# epoch 9: valid acc = 0.346, new learning rate = 0.000630249409724609
# epoch 10: valid acc = 0.342, new learning rate = 0.0005987369392383785
# epoch 11: valid acc = 0.346, new learning rate = 0.0005688000922764595
# epoch 12: valid acc = 0.35, new learning rate = 0.0005403600876626365
# epoch 13: valid acc = 0.36, new learning rate = 0.0005133420832795047
# epoch 14: valid acc = 0.366, new learning rate = 0.00048767497911552944
# epoch 15: valid acc = 0.356, new learning rate = 0.00046329123015975297
# epoch 16: valid acc = 0.364, new learning rate = 0.0004401266686517653
# epoch 17: valid acc = 0.362, new learning rate = 0.00041812033521917703
# epoch 18: valid acc = 0.36, new learning rate = 0.00039721431845821814
# epoch 19: valid acc = 0.358, new learning rate = 0.0003773536025353072
# epoch 20: valid acc = 0.378, new learning rate = 0.0003584859224085418

# %%
# plot loss curve
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Loss curve")
plt.plot(hist_dropout_01[0], label = 'Dropout = 0.1')
plt.plot(hist_dropout_05[0], label = 'Dropout = 0.5')
plt.plot(hist_dropout_07[0], label = 'Dropout = 0.7')
plt.plot(hist_dropout_09[0], label = 'Dropout = 0.9')
plt.plot(hist_no_dropout[0], label = 'Dropout = 1.0')
plt.legend()
plt.show()

# %%
# plot train acc
plt.xlabel("Epochs")
plt.ylabel("Train accuracy")
plt.title("Train accu curve")
plt.plot(hist_dropout_01[1], label = 'Dropout = 0.1')
plt.plot(hist_dropout_05[1], label = 'Dropout = 0.5')
plt.plot(hist_dropout_07[1], label = 'Dropout = 0.7')
plt.plot(hist_dropout_09[1], label = 'Dropout = 0.9')
plt.plot(hist_no_dropout[1], label = 'Dropout = 1.0')
plt.legend()
plt.show()

# %%
# plot val acc
plt.xlabel("Epochs")
plt.ylabel("Validation accuracy")
plt.title("Val accu curve")
plt.plot(hist_dropout_01[2], label = 'Dropout = 0.1')
plt.plot(hist_dropout_05[2], label = 'Dropout = 0.5')
plt.plot(hist_dropout_07[2], label = 'Dropout = 0.7')
plt.plot(hist_dropout_09[2], label = 'Dropout = 0.9')
plt.plot(hist_no_dropout[2], label = 'Dropout = 1.0')
plt.legend()
plt.show()

# %% [markdown]
# Describe findings of above dropout experiment.

# %% [markdown]
# Answer:
# 1. For loss curve we observed that loss for prob = 0.1 is very high compared to the other probabilities.
# 2. For training accuracy model with probability 0.1 has lowest training and validation accuracy that means it is underfitting data. It can be observed that the performance is insensitive to the value of p if 0.4 ≤ p ≤ 0.8. Training accuracy is maximum when probability = 1.
# 3. For validation accuracy almost all results are similar. As expected for probability = 1 validation accuracy is lower than other models but has highest training accuracy that indicates it overfits the model.
# So that's why we use dropout and keep probability is set to 0.5-0.9.

# %% [markdown]
# ## Part 2: Batch Normalization

# %% [markdown]
# ### Implement batch normalization foward function

# %%
from ecbm4040.reg_funcs import bn_forward
from ecbm4040.reg_funcs import bn_backward

np.random.seed(4040)
N, D, H1, H2 = 200, 10, 5, 3
x_in = np.random.randn(N, D)
w1 = np.random.randn(D,H1)
w2 = np.random.randn(H1,H2)
a2 = np.maximum(x_in.dot(w1),0).dot(w2)

# Before batch normalization
print("mean of a2: ", np.mean(a2, axis=0))
print("var of a2: ", np.var(a2, axis=0))

# Test "train mode" of forward function
# After batch normalization, the mean should be close to zero and var should be close to one. 
bn_config = {"epsilon":1e-5, "decay":0.9}
gamma = np.ones(H2)
beta = np.zeros(H2)
a2_bn, _ = bn_forward(a2, gamma, beta, bn_config, "train")
print("(train) mean of a2_bn: ", np.mean(a2_bn, axis=0))
print("(train) var of a2_bn: ", np.var(a2_bn, axis=0))
# Out:
# mean of a2:  [ 1.79186704 -1.67375614 -0.40317141]
# var of a2:  [ 19.78665186   3.35093598   6.67922991]
# (train) mean of a2_bn:  [  4.38538095e-16   1.67643677e-16   1.94289029e-18]
# (train) var of a2_bn:  [ 0.99999949  0.99999702  0.9999985 ]

# %%
# Test "moving average" and "test mode" of forward function
# Then you are going to run the forward function under "training mode" for several times, 
# and the moving mean and moving var will be close to the real mean and var of the input data.
# Next, run the forward function under "test" mode and you will see that the mean and var of its 
# output will be also close to gamma, beta that you have set before.

bn_config = {"epsilon":1e-5, "decay":0.9}
gamma = np.ones(H2)
beta = np.zeros(H2)

# collect_data: for calculating real mean and var of a2 later.
collect_data = a2
for _ in range(100):
    x_in = np.random.randn(N, D)
    a2 = np.maximum(x_in.dot(w1),0).dot(w2)
    collect_data = np.concatenate((collect_data, a2), axis=0)
    bn_forward(a2, gamma, beta, bn_config, "train")

# compare moving_mean and moving_var with real mean and var.
# You should see that they are close to each other.
print("real mean of data: ", np.mean(collect_data, axis=0))
print("(real var of data: ", np.var(collect_data, axis=0))
print("moving mean of data: ", bn_config["moving_mean"])
print("(moving var of data: ", bn_config["moving_var"])

# "test mode" of forward function
# After bn_forward, the mean and var of output should be kind of close to gamma and beta.
x_in = np.random.randn(N, D)
a2 = np.maximum(x_in.dot(w1),0).dot(w2)
print("*"*80)
print("mean of a2: ", np.mean(a2, axis=0))
print("var of a2: ", np.var(a2, axis=0))
a2_bn, _ = bn_forward(a2, gamma, beta, bn_config, "test")
print("(test) mean of a2_bn: ", np.mean(a2_bn, axis=0))
print("(test) var of a2_bn: ", np.var(a2_bn, axis=0))
# Out:
# real mean of data:  [ 1.666064   -1.60740475 -0.77169187]
# (real var of data:  [ 16.11643755   2.63509026   6.64151552]
# moving mean of data:  [ 1.68347874 -1.61213737 -0.78307063]
# (moving var of data:  [ 16.53922597   2.69276532   6.83992499]
# ********************************************************************************
# mean of a2:  [ 1.87970734 -1.62498121 -1.06240607]
# var of a2:  [ 13.59580536   2.85173111   5.97719192]
# (test) mean of a2_bn:  [ 0.04825081 -0.00782699 -0.10680708]
# (test) var of a2_bn:  [ 0.82203346  1.05903047  0.87386677]

# %%
# After verifying the forward function and save the bn_config.
x_in = np.random.randn(N, D)
a2 = np.maximum(x_in.dot(w1),0).dot(w2)
da2_bn = np.ones_like(a2)
# Test backward function with tensorflow
#bn_config = {"eps":1e-5, "decay":0.9, "moving_mean":moving_mean, "moving_var":moving_var}
gamma = np.ones(H2)
beta = np.zeros(H2)
a2_bn, cache = bn_forward(a2, gamma, beta, bn_config, "test")
da2, dgamma, dbeta = bn_backward(da2_bn, cache)

# Checking code below.
a2_tf = tf.Variable(a2)
eps = bn_config["epsilon"]
mean_tf = bn_config["moving_mean"]
var_tf = bn_config["moving_var"]
gamma_tf = tf.Variable(gamma)
beta_tf = tf.Variable(beta)
a2_bn_tf = tf.nn.batch_normalization(a2_tf, mean_tf, var_tf, beta_tf, gamma_tf, eps)
# derive gradients
da2_tf = tf.gradients(a2_bn_tf, a2_tf)
dgamma_tf = tf.gradients(a2_bn_tf, gamma_tf)
dbeta_tf = tf.gradients(a2_bn_tf, beta_tf)

init = tf.global_variables_initializer()
tf_output = (a2_bn_tf, da2_tf[0], dgamma_tf[0], dbeta_tf[0])
with tf.Session() as sess:
    sess.run(init)
    a2_bn_check, da2_check, dgamma_check, dbeta_check = sess.run(tf_output)
    
# Make comparison
print("Is a2_bn correct? {}".format(np.allclose(a2_bn, a2_bn_check)))
print("Is da2 correct? {}".format(np.allclose(da2, da2_check)))
print("Is dgamma correct? {}".format(np.allclose(dgamma, dgamma_check)))
print("Is dbeta correct? {}".format(np.allclose(dbeta, dbeta_check)))
# Out:
# Is a2_bn correct? True
# Is da2 correct? True
# Is dgamma correct? True
# Is dbeta correct? True

# %% [markdown]
# ### Experiments with MLP
#
# 1. Add batch normalization into MLP. Please understand **loss**, **predict** function of class **MLP** in **./ecbm4040/neuralnets/mlp.py**
#
# 2. First create a shallow MLP like two-layer network like [100,10]. And train it without/with batch normalization. Plot the loss, train accuracy and valid accuracy curve.
#
# 3. Then, create a 5-layer MLP network like [100,50,50,50,10] and train the network with/without batch normalization. Again, Plot the loss, train accuracy and valid accuracy curve.
#
# 4. Make a comparison and describe what you have found in this experiment.

# %% [markdown]
# **Experiment on shallow MLP**

# %%
# Build a two-layer netowrk without batch normalization.
# Here is a demo.
use_bn = False
model = MLP(input_dim=3072, hidden_dims=[100], num_classes=10, 
            weight_scale=1e-3, l2_reg=0.0, use_bn=use_bn)
optimizer = AdamOptim(model)
# hist_shallow_no_bn contains loss, train acc and valid acc history.
hist_shallow_no_bn = optimizer.train(model, X_train, y_train, X_val, y_val, 
                           num_epoch=50, batch_size=100, learning_rate=1e-3, learning_decay=0.95, 
                           verbose=False, record_interval = 4)
# Out:
# number of batches for training: 20
# epoch 1: valid acc = 0.244, new learning rate = 0.00095
# epoch 2: valid acc = 0.274, new learning rate = 0.0009025
# epoch 3: valid acc = 0.308, new learning rate = 0.000857375
# epoch 4: valid acc = 0.328, new learning rate = 0.0008145062499999999
# epoch 5: valid acc = 0.352, new learning rate = 0.0007737809374999998
# epoch 6: valid acc = 0.334, new learning rate = 0.0007350918906249997
# epoch 7: valid acc = 0.368, new learning rate = 0.0006983372960937497
# epoch 8: valid acc = 0.356, new learning rate = 0.0006634204312890621
# epoch 9: valid acc = 0.354, new learning rate = 0.000630249409724609
# epoch 10: valid acc = 0.346, new learning rate = 0.0005987369392383785
# epoch 11: valid acc = 0.342, new learning rate = 0.0005688000922764595
# epoch 12: valid acc = 0.352, new learning rate = 0.0005403600876626365
# epoch 13: valid acc = 0.348, new learning rate = 0.0005133420832795047
# epoch 14: valid acc = 0.356, new learning rate = 0.00048767497911552944
# epoch 15: valid acc = 0.35, new learning rate = 0.00046329123015975297
# epoch 16: valid acc = 0.33, new learning rate = 0.0004401266686517653
# epoch 17: valid acc = 0.328, new learning rate = 0.00041812033521917703
# epoch 18: valid acc = 0.342, new learning rate = 0.00039721431845821814
# epoch 19: valid acc = 0.352, new learning rate = 0.0003773536025353072
# epoch 20: valid acc = 0.346, new learning rate = 0.0003584859224085418
# epoch 21: valid acc = 0.338, new learning rate = 0.0003405616262881147
# epoch 22: valid acc = 0.346, new learning rate = 0.00032353354497370894
# epoch 23: valid acc = 0.35, new learning rate = 0.00030735686772502346
# epoch 24: valid acc = 0.334, new learning rate = 0.00029198902433877225
# epoch 25: valid acc = 0.35, new learning rate = 0.00027738957312183364
# epoch 26: valid acc = 0.36, new learning rate = 0.0002635200944657419
# epoch 27: valid acc = 0.364, new learning rate = 0.0002503440897424548
# epoch 28: valid acc = 0.362, new learning rate = 0.00023782688525533205
# epoch 29: valid acc = 0.348, new learning rate = 0.00022593554099256544
# epoch 30: valid acc = 0.36, new learning rate = 0.00021463876394293716
# epoch 31: valid acc = 0.364, new learning rate = 0.0002039068257457903
# epoch 32: valid acc = 0.366, new learning rate = 0.00019371148445850077
# epoch 33: valid acc = 0.358, new learning rate = 0.00018402591023557573
# epoch 34: valid acc = 0.354, new learning rate = 0.00017482461472379692
# epoch 35: valid acc = 0.352, new learning rate = 0.00016608338398760707
# epoch 36: valid acc = 0.344, new learning rate = 0.0001577792147882267
# epoch 37: valid acc = 0.352, new learning rate = 0.00014989025404881537
# epoch 38: valid acc = 0.36, new learning rate = 0.00014239574134637458
# epoch 39: valid acc = 0.356, new learning rate = 0.00013527595427905584
# epoch 40: valid acc = 0.352, new learning rate = 0.00012851215656510304
# epoch 41: valid acc = 0.358, new learning rate = 0.00012208654873684788
# epoch 42: valid acc = 0.364, new learning rate = 0.00011598222130000548
# epoch 43: valid acc = 0.36, new learning rate = 0.00011018311023500519
# epoch 44: valid acc = 0.356, new learning rate = 0.00010467395472325493
# epoch 45: valid acc = 0.358, new learning rate = 9.944025698709218e-05
# epoch 46: valid acc = 0.36, new learning rate = 9.446824413773756e-05
# epoch 47: valid acc = 0.352, new learning rate = 8.974483193085068e-05
# epoch 48: valid acc = 0.348, new learning rate = 8.525759033430814e-05
# epoch 49: valid acc = 0.35, new learning rate = 8.099471081759274e-05
# epoch 50: valid acc = 0.352, new learning rate = 7.69449752767131e-05

# %%
# Build a two-layer netowrk with batch normalization. Remember to "use_bn".
use_bn = True
model = MLP(input_dim=3072, hidden_dims=[100], num_classes=10, 
            weight_scale=1e-3, l2_reg=0.0, use_bn=use_bn)
optimizer = AdamOptim(model)
# hist_shallow_no_bn contains loss, train acc and valid acc history.
hist_shallow_bn = optimizer.train(model, X_train, y_train, X_val, y_val, 
                           num_epoch=50, batch_size=100, learning_rate=1e-3, learning_decay=0.95, 
                           verbose=False, record_interval = 4)
# Out:
# number of batches for training: 20
# epoch 1: valid acc = 0.204, new learning rate = 0.00095
# epoch 2: valid acc = 0.184, new learning rate = 0.0009025
# epoch 3: valid acc = 0.194, new learning rate = 0.000857375
# epoch 4: valid acc = 0.216, new learning rate = 0.0008145062499999999
# epoch 5: valid acc = 0.24, new learning rate = 0.0007737809374999998
# epoch 6: valid acc = 0.24, new learning rate = 0.0007350918906249997
# epoch 7: valid acc = 0.24, new learning rate = 0.0006983372960937497
# epoch 8: valid acc = 0.236, new learning rate = 0.0006634204312890621
# epoch 9: valid acc = 0.246, new learning rate = 0.000630249409724609
# epoch 10: valid acc = 0.242, new learning rate = 0.0005987369392383785
# epoch 11: valid acc = 0.242, new learning rate = 0.0005688000922764595
# epoch 12: valid acc = 0.238, new learning rate = 0.0005403600876626365
# epoch 13: valid acc = 0.246, new learning rate = 0.0005133420832795047
# epoch 14: valid acc = 0.248, new learning rate = 0.00048767497911552944
# epoch 15: valid acc = 0.244, new learning rate = 0.00046329123015975297
# epoch 16: valid acc = 0.25, new learning rate = 0.0004401266686517653
# epoch 17: valid acc = 0.258, new learning rate = 0.00041812033521917703
# epoch 18: valid acc = 0.252, new learning rate = 0.00039721431845821814
# epoch 19: valid acc = 0.252, new learning rate = 0.0003773536025353072
# epoch 20: valid acc = 0.258, new learning rate = 0.0003584859224085418
# epoch 21: valid acc = 0.262, new learning rate = 0.0003405616262881147
# epoch 22: valid acc = 0.262, new learning rate = 0.00032353354497370894
# epoch 23: valid acc = 0.262, new learning rate = 0.00030735686772502346
# epoch 24: valid acc = 0.264, new learning rate = 0.00029198902433877225
# epoch 25: valid acc = 0.262, new learning rate = 0.00027738957312183364
# epoch 26: valid acc = 0.26, new learning rate = 0.0002635200944657419
# epoch 27: valid acc = 0.26, new learning rate = 0.0002503440897424548
# epoch 28: valid acc = 0.262, new learning rate = 0.00023782688525533205
# epoch 29: valid acc = 0.264, new learning rate = 0.00022593554099256544
# epoch 30: valid acc = 0.264, new learning rate = 0.00021463876394293716
# epoch 31: valid acc = 0.266, new learning rate = 0.0002039068257457903
# epoch 32: valid acc = 0.266, new learning rate = 0.00019371148445850077
# epoch 33: valid acc = 0.266, new learning rate = 0.00018402591023557573
# epoch 34: valid acc = 0.272, new learning rate = 0.00017482461472379692
# epoch 35: valid acc = 0.272, new learning rate = 0.00016608338398760707
# epoch 36: valid acc = 0.272, new learning rate = 0.0001577792147882267
# epoch 37: valid acc = 0.272, new learning rate = 0.00014989025404881537
# epoch 38: valid acc = 0.272, new learning rate = 0.00014239574134637458
# epoch 39: valid acc = 0.278, new learning rate = 0.00013527595427905584
# epoch 40: valid acc = 0.28, new learning rate = 0.00012851215656510304
# epoch 41: valid acc = 0.28, new learning rate = 0.00012208654873684788
# epoch 42: valid acc = 0.28, new learning rate = 0.00011598222130000548
# epoch 43: valid acc = 0.28, new learning rate = 0.00011018311023500519
# epoch 44: valid acc = 0.28, new learning rate = 0.00010467395472325493
# epoch 45: valid acc = 0.28, new learning rate = 9.944025698709218e-05
# epoch 46: valid acc = 0.28, new learning rate = 9.446824413773756e-05
# epoch 47: valid acc = 0.282, new learning rate = 8.974483193085068e-05
# epoch 48: valid acc = 0.28, new learning rate = 8.525759033430814e-05
# epoch 49: valid acc = 0.28, new learning rate = 8.099471081759274e-05
# epoch 50: valid acc = 0.278, new learning rate = 7.69449752767131e-05

# %%
# Plot both results together and make a comparison. 
title_name = ["loss", "train acc", "val acc"]
_, axarr = plt.subplots(1,3, figsize=(15,5))
for i in range(3):
    axarr[i].plot(hist_shallow_no_bn[i], label="no_bn")
    axarr[i].plot(hist_shallow_bn[i], label="bn")
    axarr[i].legend(), axarr[i].set_title(title_name[i])
plt.show()

# %% [markdown]
# **Experiment on deep MLP**

# %%
# Build a deep 5-layer netowrk without batch normalization. Remember to "use_bn".
use_bn = False
model = MLP(input_dim=3072, hidden_dims=[100, 50, 50, 50], num_classes=10, 
            weight_scale=1e-3, l2_reg=0.0, use_bn=use_bn)
optimizer = AdamOptim(model)
# hist_no_dropout contains loss, train acc and valid acc history.
hist_deep_no_bn = optimizer.train(model, X_train, y_train, X_val, y_val, 
                           num_epoch=50, batch_size=100, learning_rate=1e-3, learning_decay=0.95, 
                           verbose=False, record_interval = 4)
# Out:
# number of batches for training: 20
# epoch 1: valid acc = 0.086, new learning rate = 0.00095
# epoch 2: valid acc = 0.086, new learning rate = 0.0009025
# epoch 3: valid acc = 0.086, new learning rate = 0.000857375
# epoch 4: valid acc = 0.086, new learning rate = 0.0008145062499999999
# epoch 5: valid acc = 0.086, new learning rate = 0.0007737809374999998
# epoch 6: valid acc = 0.086, new learning rate = 0.0007350918906249997
# epoch 7: valid acc = 0.086, new learning rate = 0.0006983372960937497
# epoch 8: valid acc = 0.086, new learning rate = 0.0006634204312890621
# epoch 9: valid acc = 0.086, new learning rate = 0.000630249409724609
# epoch 10: valid acc = 0.086, new learning rate = 0.0005987369392383785
# epoch 11: valid acc = 0.086, new learning rate = 0.0005688000922764595
# epoch 12: valid acc = 0.086, new learning rate = 0.0005403600876626365
# epoch 13: valid acc = 0.086, new learning rate = 0.0005133420832795047
# epoch 14: valid acc = 0.086, new learning rate = 0.00048767497911552944
# epoch 15: valid acc = 0.086, new learning rate = 0.00046329123015975297
# epoch 16: valid acc = 0.086, new learning rate = 0.0004401266686517653
# epoch 17: valid acc = 0.086, new learning rate = 0.00041812033521917703
# epoch 18: valid acc = 0.086, new learning rate = 0.00039721431845821814
# epoch 19: valid acc = 0.086, new learning rate = 0.0003773536025353072
# epoch 20: valid acc = 0.086, new learning rate = 0.0003584859224085418
# epoch 21: valid acc = 0.086, new learning rate = 0.0003405616262881147
# epoch 22: valid acc = 0.086, new learning rate = 0.00032353354497370894
# epoch 23: valid acc = 0.086, new learning rate = 0.00030735686772502346
# epoch 24: valid acc = 0.086, new learning rate = 0.00029198902433877225
# epoch 25: valid acc = 0.086, new learning rate = 0.00027738957312183364
# epoch 26: valid acc = 0.086, new learning rate = 0.0002635200944657419
# epoch 27: valid acc = 0.086, new learning rate = 0.0002503440897424548
# epoch 28: valid acc = 0.086, new learning rate = 0.00023782688525533205
# epoch 29: valid acc = 0.086, new learning rate = 0.00022593554099256544
# epoch 30: valid acc = 0.086, new learning rate = 0.00021463876394293716
# epoch 31: valid acc = 0.086, new learning rate = 0.0002039068257457903
# epoch 32: valid acc = 0.086, new learning rate = 0.00019371148445850077
# epoch 33: valid acc = 0.086, new learning rate = 0.00018402591023557573
# epoch 34: valid acc = 0.086, new learning rate = 0.00017482461472379692
# epoch 35: valid acc = 0.086, new learning rate = 0.00016608338398760707
# epoch 36: valid acc = 0.086, new learning rate = 0.0001577792147882267
# epoch 37: valid acc = 0.086, new learning rate = 0.00014989025404881537
# epoch 38: valid acc = 0.086, new learning rate = 0.00014239574134637458
# epoch 39: valid acc = 0.086, new learning rate = 0.00013527595427905584
# epoch 40: valid acc = 0.086, new learning rate = 0.00012851215656510304
# epoch 41: valid acc = 0.086, new learning rate = 0.00012208654873684788
# epoch 42: valid acc = 0.086, new learning rate = 0.00011598222130000548
# epoch 43: valid acc = 0.086, new learning rate = 0.00011018311023500519
# epoch 44: valid acc = 0.086, new learning rate = 0.00010467395472325493
# epoch 45: valid acc = 0.086, new learning rate = 9.944025698709218e-05
# epoch 46: valid acc = 0.086, new learning rate = 9.446824413773756e-05
# epoch 47: valid acc = 0.086, new learning rate = 8.974483193085068e-05
# epoch 48: valid acc = 0.086, new learning rate = 8.525759033430814e-05
# epoch 49: valid acc = 0.086, new learning rate = 8.099471081759274e-05
# epoch 50: valid acc = 0.086, new learning rate = 7.69449752767131e-05

# %%
# Build a deep 5-layer netowrk with batch normalization. Remember to "use_bn".
use_bn = True
model = MLP(input_dim=3072, hidden_dims=[100, 50, 50, 50], num_classes=10, 
            weight_scale=1e-3, l2_reg=0.0, use_bn=use_bn)
optimizer = AdamOptim(model)
# hist_no_dropout contains loss, train acc and valid acc history.
hist_deep_bn = optimizer.train(model, X_train, y_train, X_val, y_val, 
                           num_epoch=50, batch_size=100, learning_rate=1e-3, learning_decay=0.95, 
                           verbose=False, record_interval = 4)
# Out:
# number of batches for training: 20
# epoch 1: valid acc = 0.166, new learning rate = 0.00095
# epoch 2: valid acc = 0.15, new learning rate = 0.0009025
# epoch 3: valid acc = 0.14, new learning rate = 0.000857375
# epoch 4: valid acc = 0.136, new learning rate = 0.0008145062499999999
# epoch 5: valid acc = 0.102, new learning rate = 0.0007737809374999998
# epoch 6: valid acc = 0.112, new learning rate = 0.0007350918906249997
# epoch 7: valid acc = 0.14, new learning rate = 0.0006983372960937497
# epoch 8: valid acc = 0.148, new learning rate = 0.0006634204312890621
# epoch 9: valid acc = 0.15, new learning rate = 0.000630249409724609
# epoch 10: valid acc = 0.148, new learning rate = 0.0005987369392383785
# epoch 11: valid acc = 0.15, new learning rate = 0.0005688000922764595
# epoch 12: valid acc = 0.152, new learning rate = 0.0005403600876626365
# epoch 13: valid acc = 0.152, new learning rate = 0.0005133420832795047
# epoch 14: valid acc = 0.152, new learning rate = 0.00048767497911552944
# epoch 15: valid acc = 0.152, new learning rate = 0.00046329123015975297
# epoch 16: valid acc = 0.152, new learning rate = 0.0004401266686517653
# epoch 17: valid acc = 0.152, new learning rate = 0.00041812033521917703
# epoch 18: valid acc = 0.152, new learning rate = 0.00039721431845821814
# epoch 19: valid acc = 0.156, new learning rate = 0.0003773536025353072
# epoch 20: valid acc = 0.154, new learning rate = 0.0003584859224085418
# epoch 21: valid acc = 0.156, new learning rate = 0.0003405616262881147
# epoch 22: valid acc = 0.152, new learning rate = 0.00032353354497370894
# epoch 23: valid acc = 0.156, new learning rate = 0.00030735686772502346
# epoch 24: valid acc = 0.154, new learning rate = 0.00029198902433877225
# epoch 25: valid acc = 0.156, new learning rate = 0.00027738957312183364
# epoch 26: valid acc = 0.154, new learning rate = 0.0002635200944657419
# epoch 27: valid acc = 0.154, new learning rate = 0.0002503440897424548
# epoch 28: valid acc = 0.154, new learning rate = 0.00023782688525533205
# epoch 29: valid acc = 0.154, new learning rate = 0.00022593554099256544
# epoch 30: valid acc = 0.154, new learning rate = 0.00021463876394293716
# epoch 31: valid acc = 0.154, new learning rate = 0.0002039068257457903
# epoch 32: valid acc = 0.154, new learning rate = 0.00019371148445850077
# epoch 33: valid acc = 0.154, new learning rate = 0.00018402591023557573
# epoch 34: valid acc = 0.154, new learning rate = 0.00017482461472379692
# epoch 35: valid acc = 0.154, new learning rate = 0.00016608338398760707
# epoch 36: valid acc = 0.154, new learning rate = 0.0001577792147882267
# epoch 37: valid acc = 0.154, new learning rate = 0.00014989025404881537
# epoch 38: valid acc = 0.154, new learning rate = 0.00014239574134637458
# epoch 39: valid acc = 0.156, new learning rate = 0.00013527595427905584
# epoch 40: valid acc = 0.156, new learning rate = 0.00012851215656510304
# epoch 41: valid acc = 0.156, new learning rate = 0.00012208654873684788
# epoch 42: valid acc = 0.156, new learning rate = 0.00011598222130000548
# epoch 43: valid acc = 0.156, new learning rate = 0.00011018311023500519
# epoch 44: valid acc = 0.156, new learning rate = 0.00010467395472325493
# epoch 45: valid acc = 0.156, new learning rate = 9.944025698709218e-05
# epoch 46: valid acc = 0.156, new learning rate = 9.446824413773756e-05
# epoch 47: valid acc = 0.156, new learning rate = 8.974483193085068e-05
# epoch 48: valid acc = 0.156, new learning rate = 8.525759033430814e-05
# epoch 49: valid acc = 0.156, new learning rate = 8.099471081759274e-05
# epoch 50: valid acc = 0.156, new learning rate = 7.69449752767131e-05

# %%
# Plot both results together and make a comparison. 
title_name = ["loss", "train acc", "val acc"]
_, axarr = plt.subplots(1,3, figsize=(15,5))
for i in range(3):
    axarr[i].plot(hist_deep_no_bn[i], label="no_bn")
    axarr[i].plot(hist_deep_bn[i], label="bn")
    axarr[i].legend(), axarr[i].set_title(title_name[i])
plt.show()

# %% [markdown]
# Describe findings from above experiment.

# %% [markdown]
# Answer: We can see clearly that for shallow network batch normalization didn't work well and for deep networks batch normalization works well and gives improvement.
# Batch normalization works for deeper networks because it reduces the dependence of gradients on the scale of the parameters or their initial values and as number of layers increases effect of dependence on scale of parameters increases. So batch normalization works well for deeper networks and for shallow networks of 2 layers we can't see impact of scale of features.
#
# Other advantages of batch normalization are as follows:
# 1. Reduces internal covariant shift
# 2. Regularizes the model and reduces the need for dropout, photometric distortions, local response normalization and other regularization techniques.
# 3. Allows use of saturating nonlinearities and higher learning rates.

# %% [markdown]
# ## Reference
# * Weight Normalization: A Simple Reparameterization to Accelerate Training of Deep Neural Networks https://arxiv.org/abs/1602.07868
# * Highway netowrk https://arxiv.org/pdf/1505.00387.pdf
